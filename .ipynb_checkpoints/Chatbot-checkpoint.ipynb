# %% [markdown]
# # Markdown cell

# %%
# !pip install --quiet streamlit

# %%
# %%writefile SWMChat.py
import streamlit as st
st.set_page_config(page_title="Aplicación Streamlit", page_icon="⚙️", layout="centered")

# %%
# !streamlit run imc-streamlit.py --server.port 8502
# Out:
# Hello World!
